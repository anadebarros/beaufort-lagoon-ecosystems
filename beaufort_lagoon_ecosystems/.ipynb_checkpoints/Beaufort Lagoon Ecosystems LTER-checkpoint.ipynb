# %% [markdown]
# Observe our dataset

# %%
import pandas as pd

dataframe = pd.read_csv('BLE_LTER_sea_ice_measurements.csv', parse_dates=["date_time"]) #transforming date_time colum into a Datetime

# %%
#get only the columns we want
df = pd.DataFrame(dataframe, columns=['lagoon','station_name','date_time','hole1_ice_thickness_m','hole2_ice_thickness_m',
                                'hole3_ice_thickness_m', 'spot1_snow_depth_m', 'spot2_snow_depth_m', 'spot3_snow_depth_m',
                                'spot4_snow_depth_m','spot5_snow_depth_m', 'spot6_snow_depth_m', 'spot7_snow_depth_m','spot8_snow_depth_m',
                                'spot9_snow_depth_m','spot10_snow_depth_m', 'freeboard_m', 'latitude', 'longitude', 'station'])

df.head()
# Out:
#     lagoon                   station_name                 date_time  \
# 0  Simpson  Simpson Lagoon Deep Station 1 2019-04-21 12:21:00-08:00
# 1  Simpson  Simpson Lagoon Deep Station 1 2021-04-23 12:20:00-08:00
# 2  Simpson  Simpson Lagoon Deep Station 1 2022-04-18 12:16:00-08:00
# 3  Simpson  Simpson Lagoon Deep Station 1 2023-04-20 11:12:00-08:00
# 4  Simpson  Simpson Lagoon Deep Station 2 2023-04-23 12:51:00-08:00
#
#    hole1_ice_thickness_m  hole2_ice_thickness_m  hole3_ice_thickness_m  \
# 0                   1.32                    NaN                    NaN
# 1                   1.71                    NaN                    NaN
# 2                   1.53                    NaN                    NaN
# 3                   1.40                    1.2                    NaN
# 4                   1.30                    NaN                    NaN
#
#    spot1_snow_depth_m  spot2_snow_depth_m  spot3_snow_depth_m  \
# 0                0.29                 NaN                 NaN
# 1                0.07                 NaN                 NaN
# 2                0.09                0.15                0.07
# 3                0.04                0.09                0.08
# 4                0.10                0.10                0.11
#
#    spot4_snow_depth_m  spot5_snow_depth_m  spot6_snow_depth_m  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                0.08                0.08                0.05
# 3                0.37                0.41                0.16
# 4                0.11                0.15                0.06
#
#    spot7_snow_depth_m  spot8_snow_depth_m  spot9_snow_depth_m  \
# 0                 NaN                 NaN                 NaN
# 1                 NaN                 NaN                 NaN
# 2                0.12                0.16                0.12
# 3                0.26                0.17                0.25
# 4                0.14                0.08                0.17
#
#    spot10_snow_depth_m  freeboard_m   latitude   longitude station
# 0                  NaN         0.01  70.537067 -149.775350   SILD1
# 1                  NaN         0.10  70.537067 -149.775350   SILD1
# 2                 0.11         0.11  70.537067 -149.775350   SILD1
# 3                 0.13         0.08  70.537067 -149.775350   SILD1
# 4                 0.15         0.05  70.539883 -149.476583   SILD2

# %% [markdown]
# Display the locations of the different lagoons on a map

# %%
# I want to display the locations of the different measuring stations on a map
# I pivoted my dataframe to group by station name and get only latitude/longitude
# I used reset_index because this gives me a multi-index df. this way it is easier to acces my values
geo_df = pd.pivot_table(df, values=['latitude','longitude'], index=['station_name']).reset_index()

#get the name of the station, lat and long into a dictionary
data = { 'Station': geo_df.iloc[::]['station_name'], #this is how I can access my colum in a multi-index df
        'Latitude': geo_df.iloc[::]['latitude'],
        'Longitude': geo_df.iloc[::]['longitude']    
        }
#transform it into a dataframe again
geo_df2 = pd.DataFrame(data)

# %%
import folium
import io
from PIL import Image

# Create a Folium map centered at the mean of the coordinates
map_center = [geo_df2['Latitude'].mean(), geo_df2['Longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=4)

# Add markers for each location
for index, row in geo_df2.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']], popup=row['Station']).add_to(mymap)

#save map to png, instead of displaying it only when online
img_data = mymap._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('measuring_stations_lagoons.png')


# Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16403d081ce20f2ae2d4b5c3547d8457 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16403d081ce20f2ae2d4b5c3547d8457&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16403d081ce20f2ae2d4b5c3547d8457 = L.map(
#                 &quot;map_16403d081ce20f2ae2d4b5c3547d8457&quot;,
#                 {
#                     center: [70.62252469166667, -149.53500916666664],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7dd8b62219e6946aa7a7cbdda0c33da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7dd8b62219e6946aa7a7cbdda0c33da.addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#             var marker_bba132cedc80c1dfd2ed7a1513f63774 = L.marker(
#                 [71.29286, -156.19644],
#                 {}
#             ).addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#         var popup_a82d3d3cbcf8b4d427e494f4d75fa2e8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_60def0dfd24d2aa4a847a34aa5978466 = $(`&lt;div id=&quot;html_60def0dfd24d2aa4a847a34aa5978466&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elson East Lagoon Deep Station 1&lt;/div&gt;`)[0];
#                 popup_a82d3d3cbcf8b4d427e494f4d75fa2e8.setContent(html_60def0dfd24d2aa4a847a34aa5978466);
#
#
#
#         marker_bba132cedc80c1dfd2ed7a1513f63774.bindPopup(popup_a82d3d3cbcf8b4d427e494f4d75fa2e8)
#         ;
#
#
#
#
#             var marker_e366c126911cd941f67fae3752ec12eb = L.marker(
#                 [71.358223, -156.36044],
#                 {}
#             ).addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#         var popup_44e2a05c2e2f9e1c26385952e37eeb86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1518b41de87c6e0fe330068ada20adf4 = $(`&lt;div id=&quot;html_1518b41de87c6e0fe330068ada20adf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elson West Lagoon Craig E Tweedie 0&lt;/div&gt;`)[0];
#                 popup_44e2a05c2e2f9e1c26385952e37eeb86.setContent(html_1518b41de87c6e0fe330068ada20adf4);
#
#
#
#         marker_e366c126911cd941f67fae3752ec12eb.bindPopup(popup_44e2a05c2e2f9e1c26385952e37eeb86)
#         ;
#
#
#
#
#             var marker_9208db761a25e5be49a7d8f8d574f98d = L.marker(
#                 [71.3379, -156.4165],
#                 {}
#             ).addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#         var popup_fcb5626d514c9fe7dce924ff6ee4394a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b1fe88b22180caf8611d13e39cb59c80 = $(`&lt;div id=&quot;html_b1fe88b22180caf8611d13e39cb59c80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elson West Lagoon Deep Station 1&lt;/div&gt;`)[0];
#                 popup_fcb5626d514c9fe7dce924ff6ee4394a.setContent(html_b1fe88b22180caf8611d13e39cb59c80);
#
#
#
#         marker_9208db761a25e5be49a7d8f8d574f98d.bindPopup(popup_fcb5626d514c9fe7dce924ff6ee4394a)
#         ;
#
#
#
#
#             var marker_a33e5b4852905fcc5606dda2201caa55 = L.marker(
#                 [71.31048, -156.28778],
#                 {}
#             ).addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#         var popup_81ddb25f6248edaf81f7b98cb2dc3601 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21e877d7b47d9720538a406fe84980b4 = $(`&lt;div id=&quot;html_21e877d7b47d9720538a406fe84980b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Elson West Lagoon Deep Station 2&lt;/div&gt;`)[0];
#                 popup_81ddb25f6248edaf81f7b98cb2dc3601.setContent(html_21e877d7b47d9720538a406fe84980b4);
#
#
#
#         marker_a33e5b4852905fcc5606dda2201caa55.bindPopup(popup_81ddb25f6248edaf81f7b98cb2dc3601)
#         ;
#
#
#
#
#             var marker_93ab609aaf2e7eeae088a7e8daae7a1e = L.marker(
#                 [70.1040667, -143.48925],
#                 {}
#             ).addTo(map_16403d081ce20f2ae2d4b5c3547d8457);
#
#
#         var popup_b0cfed826b12569edf53bd0f263edbf4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_02a889fd93ca1edd67e4419ecbdb8924 = $(`&lt;div id=&quot;html_02a889fd93ca1edd67e4419ecbdb8924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Jago Lagoon Deep Station 1&lt;/div&gt;`)[0];
#                 popup_b0cfed826b12569edf53bd0f263edbf4.setContent(html_02a889fd93ca1edd67e4419ecbdb8924);
#
#
#
#         marker_93ab609aaf2e7eeae088a7e8daae7a1e.bindPopup(popup_b0cfed826b12569edf53bd0f263edbf4)
#         ;
#
#
#
#
#             var marker_1b1e70831cf55f2492909d1fcb4f13e6 = L.marker(

# %% [markdown]
# Explore ice thickness measurements

# %%
#pivot my df to aggregate by lagoon and date_time regarding ice thickness only
df1 = pd.pivot_table(df, values=['hole1_ice_thickness_m', 'hole2_ice_thickness_m', 'hole3_ice_thickness_m'],
                     index=['lagoon','station_name', 'date_time'])
df1.head()
# Out:
#                                                                           hole1_ice_thickness_m  \
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2019-04-16 12:25:00-08:00                   1.30
#                                                2021-04-27 11:15:00-08:00                   1.35
#                                                2022-04-13 14:05:00-08:00                   1.32
#                                                2023-04-20 16:30:00-08:00                   1.15
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00                   1.61
#
#                                                                           hole2_ice_thickness_m  \
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2019-04-16 12:25:00-08:00                    NaN
#                                                2021-04-27 11:15:00-08:00                    NaN
#                                                2022-04-13 14:05:00-08:00                    NaN
#                                                2023-04-20 16:30:00-08:00                    1.3
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00                    NaN
#
#                                                                           hole3_ice_thickness_m
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2019-04-16 12:25:00-08:00                    NaN
#                                                2021-04-27 11:15:00-08:00                    NaN
#                                                2022-04-13 14:05:00-08:00                    NaN
#                                                2023-04-20 16:30:00-08:00                   1.32
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00                    NaN

# %%
# Calculate the mean and standard deviation of different ice holes
# “index” (axis=0, default), “columns” (axis=1) (int this case I wanted the mean from the different columns, so I passed 1)
# by default, it is excluding missing (NaN) data
ice_df = df1.agg(['mean', 'std'], axis=1)
ice_df.head()
# Out:
#                                                                               mean  \
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2019-04-16 12:25:00-08:00  1.300000
#                                                2021-04-27 11:15:00-08:00  1.350000
#                                                2022-04-13 14:05:00-08:00  1.320000
#                                                2023-04-20 16:30:00-08:00  1.256667
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00  1.610000
#
#                                                                                std
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2019-04-16 12:25:00-08:00       NaN
#                                                2021-04-27 11:15:00-08:00       NaN
#                                                2022-04-13 14:05:00-08:00       NaN
#                                                2023-04-20 16:30:00-08:00  0.092916
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00       NaN

# %%
#which is the highest and lowest ice depth measurment?
#check to which indice the max and min values belong to

max_ice_thickness = ice_df.max()
print(max_ice_thickness)
print(ice_df.idxmax())

min_ice_thickness = ice_df.min()
print(min_ice_thickness)
print(ice_df.idxmin())
# Out:
# mean    1.880000
# std     0.141421
# dtype: float64
# mean    (Stefansson, Stefansson Sound Deep Station 2, ...
# std     (Simpson, Simpson Lagoon Deep Station 1, 2023-...
# dtype: object
# mean    1.15
# std     0.05
# dtype: float64
# mean    (Elson West, Elson West Lagoon Deep Station 1,...
# std     (Elson West, Elson West Lagoon Deep Station 1,...
# dtype: object

# %% [markdown]
# The maximum ice thickness measurement was 1.88 meters, taken at Stefansson lagoon deep station 2, in April 2023
# The minimum ice thickness measurement was 1.15 meters, taken at Elson West lagoon deep station 1, in April 2023

# %%
# could not reset index before, as it would not allow me to calculate the mean of the columns
ice_df_reset = ice_df.reset_index()
ice_df_reset.head()
# Out:
#        lagoon                         station_name                 date_time  \
# 0  Elson East     Elson East Lagoon Deep Station 1 2019-04-16 12:25:00-08:00
# 1  Elson East     Elson East Lagoon Deep Station 1 2021-04-27 11:15:00-08:00
# 2  Elson East     Elson East Lagoon Deep Station 1 2022-04-13 14:05:00-08:00
# 3  Elson East     Elson East Lagoon Deep Station 1 2023-04-20 16:30:00-08:00
# 4  Elson West  Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00
#
#        mean       std
# 0  1.300000       NaN
# 1  1.350000       NaN
# 2  1.320000       NaN
# 3  1.256667  0.092916
# 4  1.610000       NaN

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(10,6))

for lagoon in ice_df_reset['lagoon'].unique():
    lagoon_df = ice_df_reset[ice_df_reset['lagoon'] == lagoon]
    plt.scatter(lagoon_df['date_time'], lagoon_df['mean'], label=lagoon)

plt.xlabel('Date')
plt.ylabel('Ice Thickness')

# Set the size of the y-axis
plt.ylim(1, 2)

plt.title('Mean Ice Thickness per Lagoon over Time (m)')

plt.legend(title="Lagoons", loc="upper left", fontsize="small", bbox_to_anchor=(1.05, 1))

plt.savefig('Mean Ice Thickness per lagoon.jpg', bbox_inches='tight')

plt.show()

# %%
import seaborn as sns

# Set the size of the plot
plt.figure(figsize=(8, 6))  # Width, height in inches

for station in ice_df_reset['station_name'].unique():  
    station_df = ice_df_reset[ice_df_reset['station_name'] == station]  
    sns.lineplot(x=station_df['date_time'], y=station_df['mean'], data=station_df, marker='o',label=station) # Style used to mark the join between 2 points


plt.xlabel('Date')
plt.ylabel('Ice Thickness (m)')
plt.yticks(fontsize=11)
plt.title('Mean Ice Thickness per Lagoon Station over Time (m)')
plt.legend(title="Measurement stations", loc="upper left", fontsize="small", bbox_to_anchor=(1.05, 1))

plt.savefig('Mean Ice Thickness per station.jpg', bbox_inches='tight')

plt.show()

# %% [markdown]
# Explore snow depth measurements, the same way we did for ice thickness

# %%
df2 = pd.pivot_table(df, values=['spot1_snow_depth_m', 'spot2_snow_depth_m', 'spot3_snow_depth_m',
                                'spot4_snow_depth_m','spot5_snow_depth_m', 'spot6_snow_depth_m', 
                                 'spot7_snow_depth_m','spot8_snow_depth_m',
                                'spot9_snow_depth_m','spot10_snow_depth_m'], index = ['lagoon','station_name', 'date_time'])

snow_df= df2.agg(['mean', 'std'], axis=1)
snow_df.head()
# Out:
#                                                                            mean  \
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2021-04-27 11:15:00-08:00  0.120
#                                                2022-04-13 14:05:00-08:00  0.200
#                                                2023-04-20 16:30:00-08:00  0.269
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00  0.150
#            Elson West Lagoon Deep Station 1    2019-04-15 18:30:00-08:00  0.314
#
#                                                                                std
# lagoon     station_name                        date_time
# Elson East Elson East Lagoon Deep Station 1    2021-04-27 11:15:00-08:00       NaN
#                                                2022-04-13 14:05:00-08:00       NaN
#                                                2023-04-20 16:30:00-08:00  0.039567
# Elson West Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00       NaN
#            Elson West Lagoon Deep Station 1    2019-04-15 18:30:00-08:00  0.079875

# %%
#which is the highest and lowest snow depth measurement?
#check to which indice the max and min values belong to

max_snow_depth = snow_df.max()
print(max_snow_depth)
print(snow_df.idxmax())

min_snow_depth = snow_df.min()
print(min_snow_depth)
print(snow_df.idxmin())
# Out:
# mean    0.410000
# std     0.124025
# dtype: float64
# mean    (Elson West, Elson West Lagoon Deep Station 2,...
# std     (Simpson, Simpson Lagoon Deep Station 1, 2023-...
# dtype: object
# mean    0.050000
# std     0.027968
# dtype: float64
# mean    (Stefansson, Stefansson Sound Deep Station 1, ...
# std     (Jago, Jago Lagoon Deep Station 1, 2022-04-22 ...
# dtype: object

# %% [markdown]
# The maximum snow depth was 0.41 meters, measured at Elson West lagoon deep station 2, in April 2019
# The minimum snow depth was 0.05 meters, measured at Stefansson lagoon deep station 1, in April 2021

# %%
snow_df_reset = snow_df.reset_index()
snow_df_reset.head()
# Out:
#        lagoon                         station_name                 date_time  \
# 0  Elson East     Elson East Lagoon Deep Station 1 2021-04-27 11:15:00-08:00
# 1  Elson East     Elson East Lagoon Deep Station 1 2022-04-13 14:05:00-08:00
# 2  Elson East     Elson East Lagoon Deep Station 1 2023-04-20 16:30:00-08:00
# 3  Elson West  Elson West Lagoon Craig E Tweedie 0 2022-04-18 12:00:00-08:00
# 4  Elson West     Elson West Lagoon Deep Station 1 2019-04-15 18:30:00-08:00
#
#     mean       std
# 0  0.120       NaN
# 1  0.200       NaN
# 2  0.269  0.039567
# 3  0.150       NaN
# 4  0.314  0.079875

# %%
plt.figure(figsize=(10,6))

for lagoon in snow_df_reset['lagoon'].unique():
    lagoon_df = snow_df_reset[snow_df_reset['lagoon'] == lagoon]
    plt.scatter(lagoon_df['date_time'], lagoon_df['mean'], label=lagoon)

plt.xlabel('Date')
plt.ylabel('Snow depth')

plt.ylim(0, 0.5)

plt.title('Mean Snow Depth per Lagoon over Time (m)')

plt.legend(title="Lagoons", loc="upper left", fontsize="small", bbox_to_anchor=(1.05, 1))

plt.savefig('Mean Snow Depth Lagoon.jpg', bbox_inches='tight')


plt.show()

# %%
plt.figure(figsize=(8, 6))  # Width, height in inches

for station in snow_df_reset['station_name'].unique():  
    station_df = snow_df_reset[snow_df_reset['station_name'] == station]  
    sns.lineplot(x=station_df['date_time'], y=station_df['mean'], data=station_df, marker='o',label=station) # Style used to mark the join between 2 points


plt.xlabel('Date')
plt.ylabel('Snow Depth (m)')
plt.yticks(fontsize=11)
plt.title('Mean Snow Depth per Lagoon Station over Time (m)')
plt.legend(title="Measurement stations", loc="upper left", fontsize="small", bbox_to_anchor=(1.05, 1))

plt.savefig('Mean Snow Depth Station.jpg', bbox_inches='tight')

plt.show()

# %%
correlation = ice_df['mean'].corr(snow_df['mean'])
print(correlation)
# Out:
# -0.4915485058163321

# %% [markdown]
# The correlation coefficient between ice thickness and snow depth is of -0.49 suggesting that there is a moderate negative linear relationship between the two variables.

# %%
#still working on this to calculate correlation between the two mean columns, but I'm not accessing it

concatenated_df = pd.concat([ice_df, snow_df], axis=1)
concatenated_df.head()

# %%
#correlation = concatenated_df['mean'].corr(concatenated_df['mean'])
#print(correlation)
